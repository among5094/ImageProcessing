# %%
import cv2
import mediapipe as mp

# MediaPipe 얼굴 인식 초기화
mp_face_detection = mp.solutions.face_detection #얼굴 검출을 위한 face_detection 모듈을 사용
mp_drawing = mp.solutions.drawing_utils #얼굴의 특징을 그리기 위한 drawing_utils모듈을 사용

# 비디오 캡처
cap=cv2.VideoCapture(0)

# 비디오 프레임 처리
#model_selection=0or1(0은 2m이내의 근거리, 1은 5m이내의 원거리 )
#min_detection_confidence=0.5는 50%이상의 신뢰도로 여기에 얼굴이 있는 것 같아. 라고 생각함.(임계치 개념)
with mp_face_detection.FaceDetection(model_selection=0, min_detection_confidence=0.7) as face_detection:
    #제대로 동영상이 열렸는가?
    while cap. isOpened():
        success, image=cap.read()
        if not success:
            break
            
        image.flags.writeable=False
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)#cv2.cvtColor: 프레임의 색상을 BGR에서 RGB로 변환
        results=face_detection.process(image) #변환된 이미지에서 얼굴을 인식
        
        image.flags.writeable=True
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        #검출된 얼굴이 있다면? 그림 그리기
        if results.detections:
            #6개 특징: 오른쪽 눈, 왼쪽 눈, 코 끝부분, 입 중심, 오른쪽 귀, 왼쪽 귀(귀 구슬점, 이주(귓구멍 앞부분)) 추출
            for detection in results.detections:
                #흰색 네모박스+6개의 포인트에 빨간 점 찍기
                mp_drawing.draw_detection(image, detection) #인식된 얼굴에 대해 시각적인 표시
                print(detection) #추출된 특징을 print로 확인하기
                
                #특정 위치 가져오기
                keypoints = detection.location_data.relative_keypoints
                right_eye=keypoints[0] #오른쪽 눈
                left_eye=keypoints[1] #왼쪽 눈
                nose_tip=keypoints[2] #코 끝부분 
                
                #이미지의 크기 정보를 가지고 좌표 계산하기
                h,w,_=image.shape #height, width, channel: 이미지로부터 세로, 가로 크기 가져옴
                right_eye=(int(right_eye.x*w), int(right_eye.y*h)) #이미지 내의 실제 좌표(x,y)
                left_eye=(int(left_eye.x*w), int(left_eye.y*h))
                nose_tip=(int(nose_tip.x*w), int(nose_tip.y*h))
                
                #양 눈에 동그라미 그리기 
                cv2.circle(image, right_eye, 20, (255,0,0), 10, cv2.LINE_AA) #파란색 동그라미
                cv2.circle(image, left_eye, 20, (0,255,0), 10, cv2.LINE_AA)
                
                #코에 동그라미 그리기
                cv2.circle(image, nose_tip, 20, (0,255,255), 10, cv2.LINE_AA) #빨간색 동그라미 그리기
                
        #동영상 보여주는 부분
        cv2.imshow('MediaPipe Face Detection', cv2.resize(image, None, fx=0.7, fy=0.7)) #처리된 이미지를 화면에 표시
        
        #q누르면 while문 종료
        if cv2.waitKey(1) == ord('q'):
            break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# label_id: 0
# score: 0.8258739
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36228547
#     ymin: 0.61495847
#     width: 0.34400484
#     height: 0.45863968
#   }
#   relative_keypoints {
#     x: 0.46189103
#     y: 0.73828727
#   }
#   relative_keypoints {
#     x: 0.6093578
#     y: 0.7653377
#   }
#   relative_keypoints {
#     x: 0.5249377
#     y: 0.87353975
#   }
#   relative_keypoints {
#     x: 0.5173442
#     y: 0.96035415
#   }
#   relative_keypoints {
#     x: 0.38005257
#     y: 0.7512583
#   }
#   relative_keypoints {
#     x: 0.6853228
#     y: 0.8020908
#   }
# }
#
# label_id: 0
# score: 0.83635575
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35958284
#     ymin: 0.6137722
#     width: 0.3483582
#     height: 0.46444207
#   }
#   relative_keypoints {
#     x: 0.45784995
#     y: 0.7403154
#   }
#   relative_keypoints {
#     x: 0.60520697
#     y: 0.76492673
#   }
#   relative_keypoints {
#     x: 0.5187454
#     y: 0.8763947
#   }
#   relative_keypoints {
#     x: 0.51304877
#     y: 0.9644392
#   }
#   relative_keypoints {
#     x: 0.3809583
#     y: 0.754791
#   }
#   relative_keypoints {
#     x: 0.6862048
#     y: 0.8010187
#   }
# }
#
# label_id: 0
# score: 0.82458615
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3657424
#     ymin: 0.62013316
#     width: 0.3370844
#     height: 0.44941294
#   }
#   relative_keypoints {
#     x: 0.46260557
#     y: 0.7424927
#   }
#   relative_keypoints {
#     x: 0.60734224
#     y: 0.7640342
#   }
#   relative_keypoints {
#     x: 0.52724636
#     y: 0.8711484
#   }
#   relative_keypoints {
#     x: 0.5213571
#     y: 0.957243
#   }
#   relative_keypoints {
#     x: 0.38219562
#     y: 0.75871736
#   }
#   relative_keypoints {
#     x: 0.68306994
#     y: 0.79789907
#   }
# }
#
# label_id: 0
# score: 0.8375478
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36626944
#     ymin: 0.6189904
#     width: 0.33661023
#     height: 0.44878113
#   }
#   relative_keypoints {
#     x: 0.45796162
#     y: 0.74491996
#   }
#   relative_keypoints {
#     x: 0.603656
#     y: 0.7662299
#   }
#   relative_keypoints {
#     x: 0.52021205
#     y: 0.87667805
#   }
#   relative_keypoints {
#     x: 0.5162811
#     y: 0.9597103
#   }
#   relative_keypoints {
#     x: 0.38261583
#     y: 0.7564166
#   }
#   relative_keypoints {
#     x: 0.6843733
#     y: 0.7953589
#   }
# }
#
# label_id: 0
# score: 0.820143
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36203414
#     ymin: 0.61501527
#     width: 0.34256697
#     height: 0.4567219
#   }
#   relative_keypoints {
#     x: 0.4600475
#     y: 0.742652
#   }
#   relative_keypoints {
#     x: 0.60558695
#     y: 0.76518184
#   }
#   relative_keypoints {
#     x: 0.52301264
#     y: 0.8773921
#   }
#   relative_keypoints {
#     x: 0.5176298
#     y: 0.9616731
#   }
#   relative_keypoints {
#     x: 0.38164067
#     y: 0.75501186
#   }
#   relative_keypoints {
#     x: 0.6828087
#     y: 0.7962578
#   }
# }
#
# label_id: 0
# score: 0.819997
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36251855
#     ymin: 0.61569405
#     width: 0.34140265
#     height: 0.45517004
#   }
#   relative_keypoints {
#     x: 0.4590136
#     y: 0.7418435
#   }
#   relative_keypoints {
#     x: 0.6036573
#     y: 0.7662692
#   }
#   relative_keypoints {
#     x: 0.51937705
#     y: 0.87705904
#   }
#   relative_keypoints {
#     x: 0.51376706
#     y: 0.96093875
#   }
#   relative_keypoints {
#     x: 0.38267142
#     y: 0.7521675
#   }
#   relative_keypoints {
#     x: 0.6825336
#     y: 0.79799575
#   }
# }
#
# label_id: 0
# score: 0.82766116
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3571205
#     ymin: 0.61289185
#     width: 0.34563857
#     height: 0.46081752
#   }
#   relative_keypoints {
#     x: 0.45917463
#     y: 0.7404372
#   }
#   relative_keypoints {
#     x: 0.6039252
#     y: 0.7683827
#   }
#   relative_keypoints {
#     x: 0.5203356
#     y: 0.88042
#   }
#   relative_keypoints {
#     x: 0.5125581
#     y: 0.9640767
#   }
#   relative_keypoints {
#     x: 0.37866667
#     y: 0.74716276
#   }
#   relative_keypoints {
#     x: 0.67881536
#     y: 0.79978895
#   }
# }
#
# label_id: 0
# score: 0.82789916
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3614376
#     ymin: 0.61734873
#     width: 0.34423402
#     height: 0.45894414
#   }
#   relative_keypoints {
#     x: 0.4595648
#     y: 0.7444763
#   }
#   relative_keypoints {
#     x: 0.60545933
#     y: 0.7692551
#   }
#   relative_keypoints {
#     x: 0.5211882
#     y: 0.8814133
#   }
#   relative_keypoints {
#     x: 0.5153631
#     y: 0.9664443
#   }
#   relative_keypoints {
#     x: 0.38180733
#     y: 0.75551844
#   }
#   relative_keypoints {
#     x: 0.68377155
#     y: 0.801071
#   }
# }
#
# label_id: 0
# score: 0.82230526
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36260688
#     ymin: 0.6165982
#     width: 0.34074634
#     height: 0.45429474
#   }
#   relative_keypoints {
#     x: 0.45977488
#     y: 0.73984796
#   }
#   relative_keypoints {
#     x: 0.60469943
#     y: 0.7636176
#   }
#   relative_keypoints {
#     x: 0.5215288
#     y: 0.8720371
#   }
#   relative_keypoints {
#     x: 0.5159043
#     y: 0.9581762
#   }
#   relative_keypoints {
#     x: 0.38209242
#     y: 0.75561947
#   }
#   relative_keypoints {
#     x: 0.6821626
#     y: 0.79961497
#   }
# }
#
# label_id: 0
# score: 0.82669353
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36082208
#     ymin: 0.61146826
#     width: 0.34520227
#     height: 0.4602353
#   }
#   relative_keypoints {
#     x: 0.45738205
#     y: 0.7406328
#   }
#   relative_keypoints {
#     x: 0.6027894
#     y: 0.76794934
#   }
#   relative_keypoints {
#     x: 0.51555073
#     y: 0.8816684
#   }
#   relative_keypoints {
#     x: 0.5098274
#     y: 0.964016
#   }
#   relative_keypoints {
#     x: 0.38290358
#     y: 0.7460281
#   }
#   relative_keypoints {
#     x: 0.6835728
#     y: 0.79743534
#   }
# }
#
# label_id: 0
# score: 0.8186142
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3592799
#     ymin: 0.60808533
#     width: 0.34965643
#     height: 0.46617013
#   }
#   relative_keypoints {
#     x: 0.4546123
#     y: 0.7381819
#   }
#   relative_keypoints {
#     x: 0.6007417
#     y: 0.7635289
#   }
#   relative_keypoints {
#     x: 0.5112615
#     y: 0.87839645
#   }
#   relative_keypoints {
#     x: 0.50759655
#     y: 0.9632248
#   }
#   relative_keypoints {
#     x: 0.3846722
#     y: 0.74883896
#   }
#   relative_keypoints {
#     x: 0.6859665
#     y: 0.7956827
#   }
# }
#
# label_id: 0
# score: 0.83296514
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35785672
#     ymin: 0.6115065
#     width: 0.35053858
#     height: 0.46734828
#   }
#   relative_keypoints {
#     x: 0.4526826
#     y: 0.7379708
#   }
#   relative_keypoints {
#     x: 0.6002802
#     y: 0.76684767
#   }
#   relative_keypoints {
#     x: 0.50848204
#     y: 0.8785041
#   }
#   relative_keypoints {
#     x: 0.50381184
#     y: 0.9661227
#   }
#   relative_keypoints {
#     x: 0.3817704
#     y: 0.74953145
#   }
#   relative_keypoints {
#     x: 0.68658495
#     y: 0.8035818
#   }
# }
#
# label_id: 0
# score: 0.8300421
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35480985
#     ymin: 0.6069185
#     width: 0.35586962
#     height: 0.4744497
#   }
#   relative_keypoints {
#     x: 0.45282924
#     y: 0.73811007
#   }
#   relative_keypoints {
#     x: 0.60059625
#     y: 0.76475805
#   }
#   relative_keypoints {
#     x: 0.5096069
#     y: 0.88104683
#   }
#   relative_keypoints {
#     x: 0.5055485
#     y: 0.96811646
#   }
#   relative_keypoints {
#     x: 0.3817624
#     y: 0.75013447
#   }
#   relative_keypoints {
#     x: 0.68644893
#     y: 0.7998752
#   }
# }
#
# label_id: 0
# score: 0.8033835
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36253414
#     ymin: 0.6112377
#     width: 0.34009328
#     height: 0.4534238
#   }
#   relative_keypoints {
#     x: 0.45581385
#     y: 0.7332093
#   }
#   relative_keypoints {
#     x: 0.6003465
#     y: 0.7607272
#   }
#   relative_keypoints {
#     x: 0.51186454
#     y: 0.8673902
#   }
#   relative_keypoints {
#     x: 0.5069703
#     y: 0.952908
#   }
#   relative_keypoints {
#     x: 0.38416308
#     y: 0.7474256
#   }
#   relative_keypoints {
#     x: 0.68222415
#     y: 0.79889196
#   }
# }
#
# label_id: 0
# score: 0.8213484
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36145324
#     ymin: 0.61120385
#     width: 0.34687448
#     height: 0.46246368
#   }
#   relative_keypoints {
#     x: 0.45597062
#     y: 0.7355439
#   }
#   relative_keypoints {
#     x: 0.6018306
#     y: 0.76149154
#   }
#   relative_keypoints {
#     x: 0.51163787
#     y: 0.8711328
#   }
#   relative_keypoints {
#     x: 0.5073592
#     y: 0.95947987
#   }
#   relative_keypoints {
#     x: 0.38558215
#     y: 0.7512705
#   }
#   relative_keypoints {
#     x: 0.68659323
#     y: 0.8005397
#   }
# }
#
# label_id: 0
# score: 0.8068746
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3587856
#     ymin: 0.6097699
#     width: 0.34664974
#     height: 0.46216446
#   }
#   relative_keypoints {
#     x: 0.4556996
#     y: 0.73171765
#   }
#   relative_keypoints {
#     x: 0.6019596
#     y: 0.7581222
#   }
#   relative_keypoints {
#     x: 0.51315284
#     y: 0.8652312
#   }
#   relative_keypoints {
#     x: 0.5079549
#     y: 0.955164
#   }
#   relative_keypoints {
#     x: 0.38209188
#     y: 0.7510107
#   }
#   relative_keypoints {
#     x: 0.68392926
#     y: 0.8007646
#   }
# }
#
# label_id: 0
# score: 0.81068623
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3599637
#     ymin: 0.61357695
#     width: 0.3444766
#     height: 0.45926732
#   }
#   relative_keypoints {
#     x: 0.45640713
#     y: 0.7331579
#   }
#   relative_keypoints {
#     x: 0.6019745
#     y: 0.76081175
#   }
#   relative_keypoints {
#     x: 0.5132623
#     y: 0.8658009
#   }
#   relative_keypoints {
#     x: 0.5077872
#     y: 0.95581824
#   }
#   relative_keypoints {
#     x: 0.38273922
#     y: 0.7528983
#   }
#   relative_keypoints {
#     x: 0.6834072
#     y: 0.8046666
#   }
# }
#
# label_id: 0
# score: 0.80937093
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36272472
#     ymin: 0.61083597
#     width: 0.34307313
#     height: 0.45739657
#   }
#   relative_keypoints {
#     x: 0.45636657
#     y: 0.73569053
#   }
#   relative_keypoints {
#     x: 0.6010085
#     y: 0.7604169
#   }
#   relative_keypoints {
#     x: 0.51258904
#     y: 0.870189
#   }
#   relative_keypoints {
#     x: 0.5085012
#     y: 0.9562755
#   }
#   relative_keypoints {
#     x: 0.38597676
#     y: 0.7498586
#   }
#   relative_keypoints {
#     x: 0.6843551
#     y: 0.79631567
#   }
# }
#
# label_id: 0
# score: 0.8133904
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36174613
#     ymin: 0.61050487
#     width: 0.3470847
#     height: 0.46274126
#   }
#   relative_keypoints {
#     x: 0.4554189
#     y: 0.73599213
#   }
#   relative_keypoints {
#     x: 0.60075945
#     y: 0.76513886
#   }
#   relative_keypoints {
#     x: 0.50867325
#     y: 0.87560874
#   }
#   relative_keypoints {
#     x: 0.5045782
#     y: 0.96148187
#   }
#   relative_keypoints {
#     x: 0.3875781
#     y: 0.74812573
#   }
#   relative_keypoints {
#     x: 0.6869184
#     y: 0.8022232
#   }
# }
#
# label_id: 0
# score: 0.8165899
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36403626
#     ymin: 0.6112259
#     width: 0.34325856
#     height: 0.45764345
#   }
#   relative_keypoints {
#     x: 0.45507666
#     y: 0.733546
#   }
#   relative_keypoints {
#     x: 0.6005478
#     y: 0.76127887
#   }
#   relative_keypoints {
#     x: 0.5085038
#     y: 0.8685942
#   }
#   relative_keypoints {
#     x: 0.5046797
#     y: 0.9556888
#   }
#   relative_keypoints {
#     x: 0.3871902
#     y: 0.7485165
#   }
#   relative_keypoints {
#     x: 0.6872303
#     y: 0.80095154
#   }
# }
# label_id: 0
# score: 0.8105148
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3609567
#     ymin: 0.6112292
#     width: 0.34487954
#     height: 0.45980442
#   }
#   relative_keypoints {
#     x: 0.4567308
#     y: 0.7332817
#   }
#   relative_keypoints {
#     x: 0.60175467
#     y: 0.7628317
#   }
#   relative_keypoints {
#     x: 0.511656
#     y: 0.8701822
#   }
#   relative_keypoints {
#     x: 0.5060471
#     y: 0.957686
#   }
#   relative_keypoints {
#     x: 0.38483778
#     y: 0.7472382
#   }
#   relative_keypoints {
#     x: 0.6840546
#     y: 0.8027696
#   }
# }
#
# label_id: 0
# score: 0.8032381
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36435014
#     ymin: 0.6118536
#     width: 0.3405518
#     height: 0.45403528
#   }
#   relative_keypoints {
#     x: 0.45670328
#     y: 0.7321944
#   }
#   relative_keypoints {
#     x: 0.6012261
#     y: 0.76110893
#   }
#   relative_keypoints {
#     x: 0.510589
#     y: 0.86655337
#   }
#   relative_keypoints {
#     x: 0.50561965
#     y: 0.95318395
#   }
#   relative_keypoints {
#     x: 0.38689893
#     y: 0.7470093
#   }
#   relative_keypoints {
#     x: 0.68502516
#     y: 0.8016622
#   }
# }
#
# label_id: 0
# score: 0.8279965
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35767385
#     ymin: 0.6106383
#     width: 0.3485026
#     height: 0.46463495
#   }
#   relative_keypoints {
#     x: 0.452063
#     y: 0.7366095
#   }
#   relative_keypoints {
#     x: 0.5994119
#     y: 0.762356
#   }
#   relative_keypoints {
#     x: 0.509038
#     y: 0.8732663
#   }
#   relative_keypoints {
#     x: 0.5050484
#     y: 0.9609663
#   }
#   relative_keypoints {
#     x: 0.3810641
#     y: 0.75185466
#   }
#   relative_keypoints {
#     x: 0.68517154
#     y: 0.79999787
#   }
# }
#
# label_id: 0
# score: 0.82002777
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35914835
#     ymin: 0.61249226
#     width: 0.3431423
#     height: 0.4574893
#   }
#   relative_keypoints {
#     x: 0.45374188
#     y: 0.73039484
#   }
#   relative_keypoints {
#     x: 0.6008878
#     y: 0.7610093
#   }
#   relative_keypoints {
#     x: 0.51055884
#     y: 0.8639253
#   }
#   relative_keypoints {
#     x: 0.504079
#     y: 0.953036
#   }
#   relative_keypoints {
#     x: 0.37912974
#     y: 0.74766093
#   }
#   relative_keypoints {
#     x: 0.6833423
#     y: 0.80580646
#   }
# }
#
# label_id: 0
# score: 0.815363
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36429182
#     ymin: 0.6147693
#     width: 0.3306295
#     height: 0.44080716
#   }
#   relative_keypoints {
#     x: 0.45652112
#     y: 0.72689444
#   }
#   relative_keypoints {
#     x: 0.5997497
#     y: 0.75380206
#   }
#   relative_keypoints {
#     x: 0.51467
#     y: 0.8510663
#   }
#   relative_keypoints {
#     x: 0.5082508
#     y: 0.9395258
#   }
#   relative_keypoints {
#     x: 0.38130575
#     y: 0.7480946
#   }
#   relative_keypoints {
#     x: 0.677837
#     y: 0.7997028
#   }
# }
#
# label_id: 0
# score: 0.8316673
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3638825
#     ymin: 0.6079292
#     width: 0.33381465
#     height: 0.44505417
#   }
#   relative_keypoints {
#     x: 0.4560042
#     y: 0.7287025
#   }
#   relative_keypoints {
#     x: 0.6005984
#     y: 0.7486029
#   }
#   relative_keypoints {
#     x: 0.518265
#     y: 0.85389787
#   }
#   relative_keypoints {
#     x: 0.5139939
#     y: 0.9396239
#   }
#   relative_keypoints {
#     x: 0.38046026
#     y: 0.74819493
#   }
#   relative_keypoints {
#     x: 0.67936987
#     y: 0.7860295
#   }
# }
#
# label_id: 0
# score: 0.84747756
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35974506
#     ymin: 0.5990303
#     width: 0.3421506
#     height: 0.45616812
#   }
#   relative_keypoints {
#     x: 0.455452
#     y: 0.72452575
#   }
#   relative_keypoints {
#     x: 0.6021109
#     y: 0.7490824
#   }
#   relative_keypoints {
#     x: 0.5165531
#     y: 0.8587168
#   }
#   relative_keypoints {
#     x: 0.5109694
#     y: 0.94273764
#   }
#   relative_keypoints {
#     x: 0.37903738
#     y: 0.7363994
#   }
#   relative_keypoints {
#     x: 0.681864
#     y: 0.78327304
#   }
# }
#
# label_id: 0
# score: 0.8690108
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36224625
#     ymin: 0.59618145
#     width: 0.34066197
#     height: 0.45418483
#   }
#   relative_keypoints {
#     x: 0.45390317
#     y: 0.71986604
#   }
#   relative_keypoints {
#     x: 0.59936285
#     y: 0.74121815
#   }
#   relative_keypoints {
#     x: 0.5126842
#     y: 0.85035425
#   }
#   relative_keypoints {
#     x: 0.5091941
#     y: 0.935901
#   }
#   relative_keypoints {
#     x: 0.38272217
#     y: 0.73693633
#   }
#   relative_keypoints {
#     x: 0.68337965
#     y: 0.77920914
#   }
# }
#
# label_id: 0
# score: 0.8932932
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35781264
#     ymin: 0.5899992
#     width: 0.34946483
#     height: 0.46591854
#   }
#   relative_keypoints {
#     x: 0.4499735
#     y: 0.7214861
#   }
#   relative_keypoints {
#     x: 0.5967648
#     y: 0.7365702
#   }
#   relative_keypoints {
#     x: 0.51047647
#     y: 0.8534859
#   }
#   relative_keypoints {
#     x: 0.50930333
#     y: 0.9393886
#   }
#   relative_keypoints {
#     x: 0.3817037
#     y: 0.7389679
#   }
#   relative_keypoints {
#     x: 0.68537056
#     y: 0.76930475
#   }
# }
#
# label_id: 0
# score: 0.90637213
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35247317
#     ymin: 0.57794696
#     width: 0.35890266
#     height: 0.47849756
#   }
#   relative_keypoints {
#     x: 0.45126694
#     y: 0.71611255
#   }
#   relative_keypoints {
#     x: 0.5980078
#     y: 0.7322281
#   }
#   relative_keypoints {
#     x: 0.5126602
#     y: 0.8553241
#   }
#   relative_keypoints {
#     x: 0.5106236
#     y: 0.9402804
#   }
#   relative_keypoints {
#     x: 0.3809205
#     y: 0.72990316
#   }
#   relative_keypoints {
#     x: 0.6844994
#     y: 0.76161647
#   }
# }
#
# label_id: 0
# score: 0.91259015
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35969308
#     ymin: 0.5773382
#     width: 0.3514569
#     height: 0.46857393
#   }
#   relative_keypoints {
#     x: 0.45387876
#     y: 0.7102136
#   }
#   relative_keypoints {
#     x: 0.5986521
#     y: 0.7297199
#   }
#   relative_keypoints {
#     x: 0.5107004
#     y: 0.84768325
#   }
#   relative_keypoints {
#     x: 0.5086966
#     y: 0.93172616
#   }
#   relative_keypoints {
#     x: 0.38747603
#     y: 0.7238644
#   }
#   relative_keypoints {
#     x: 0.68690825
#     y: 0.7624805
#   }
# }
#
# label_id: 0
# score: 0.91647685
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34917438
#     ymin: 0.56492615
#     width: 0.36285144
#     height: 0.4837556
#   }
#   relative_keypoints {
#     x: 0.45278355
#     y: 0.70196223
#   }
#   relative_keypoints {
#     x: 0.6001176
#     y: 0.7187461
#   }
#   relative_keypoints {
#     x: 0.51561517
#     y: 0.84062916
#   }
#   relative_keypoints {
#     x: 0.51229596
#     y: 0.92914945
#   }
#   relative_keypoints {
#     x: 0.3781549
#     y: 0.7212557
#   }
#   relative_keypoints {
#     x: 0.682949
#     y: 0.754751
#   }
# }
#
# label_id: 0
# score: 0.9197602
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3507287
#     ymin: 0.56681484
#     width: 0.35585868
#     height: 0.47443777
#   }
#   relative_keypoints {
#     x: 0.45440567
#     y: 0.7008688
#   }
#   relative_keypoints {
#     x: 0.6012706
#     y: 0.714633
#   }
#   relative_keypoints {
#     x: 0.5211446
#     y: 0.83324033
#   }
#   relative_keypoints {
#     x: 0.5175272
#     y: 0.9209325
#   }
#   relative_keypoints {
#     x: 0.37565958
#     y: 0.72310823
#   }
#   relative_keypoints {
#     x: 0.6806612
#     y: 0.75071746
#   }
# }
#
# label_id: 0
# score: 0.9343278
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3501221
#     ymin: 0.5620286
#     width: 0.35796636
#     height: 0.47725052
#   }
#   relative_keypoints {
#     x: 0.45360073
#     y: 0.695707
#   }
#   relative_keypoints {
#     x: 0.6026412
#     y: 0.7099704
#   }
#   relative_keypoints {
#     x: 0.5216415
#     y: 0.8281725
#   }
#   relative_keypoints {
#     x: 0.51790464
#     y: 0.9169857
#   }
#   relative_keypoints {
#     x: 0.3730005
#     y: 0.71851176
#   }
#   relative_keypoints {
#     x: 0.68331826
#     y: 0.74682707
#   }
# }
#
# label_id: 0
# score: 0.94522977
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35111895
#     ymin: 0.55398244
#     width: 0.35783926
#     height: 0.4770816
#   }
#   relative_keypoints {
#     x: 0.4601268
#     y: 0.68752867
#   }
#   relative_keypoints {
#     x: 0.6060021
#     y: 0.709501
#   }
#   relative_keypoints {
#     x: 0.5256728
#     y: 0.8274267
#   }
#   relative_keypoints {
#     x: 0.5184673
#     y: 0.9129701
#   }
#   relative_keypoints {
#     x: 0.37643746
#     y: 0.7005047
#   }
#   relative_keypoints {
#     x: 0.68121165
#     y: 0.74357814
#   }
# }
#
# label_id: 0
# score: 0.96159726
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35081917
#     ymin: 0.5505314
#     width: 0.35767657
#     height: 0.4768648
#   }
#   relative_keypoints {
#     x: 0.4577655
#     y: 0.6860855
#   }
#   relative_keypoints {
#     x: 0.60283816
#     y: 0.6987579
#   }
#   relative_keypoints {
#     x: 0.5254222
#     y: 0.81942886
#   }
#   relative_keypoints {
#     x: 0.52165455
#     y: 0.90650207
#   }
#   relative_keypoints {
#     x: 0.37766698
#     y: 0.70779914
#   }
#   relative_keypoints {
#     x: 0.6805004
#     y: 0.73293227
#   }
# }
#
# label_id: 0
# score: 0.9675963
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35089067
#     ymin: 0.55036587
#     width: 0.35661176
#     height: 0.47544497
#   }
#   relative_keypoints {
#     x: 0.45488238
#     y: 0.68380684
#   }
#   relative_keypoints {
#     x: 0.6007787
#     y: 0.6950529
#   }
#   relative_keypoints {
#     x: 0.5221464
#     y: 0.8146393
#   }
#   relative_keypoints {
#     x: 0.51943195
#     y: 0.9032654
#   }
#   relative_keypoints {
#     x: 0.3769507
#     y: 0.7092723
#   }
#   relative_keypoints {
#     x: 0.68131256
#     y: 0.73152155
#   }
# }
#
# label_id: 0
# score: 0.9763248
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3501365
#     ymin: 0.5477257
#     width: 0.35327283
#     height: 0.47100365
#   }
#   relative_keypoints {
#     x: 0.4574113
#     y: 0.678798
#   }
#   relative_keypoints {
#     x: 0.6015757
#     y: 0.689513
#   }
#   relative_keypoints {
#     x: 0.52672964
#     y: 0.8070107
#   }
#   relative_keypoints {
#     x: 0.5229193
#     y: 0.8948149
#   }
#   relative_keypoints {
#     x: 0.3756839
#     y: 0.7058638
#   }
#   relative_keypoints {
#     x: 0.67737883
#     y: 0.7273709
#   }
# }
#
# label_id: 0
# score: 0.96509135
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34994495
#     ymin: 0.54519457
#     width: 0.34988588
#     height: 0.46648735
#   }
#   relative_keypoints {
#     x: 0.45746225
#     y: 0.6716426
#   }
#   relative_keypoints {
#     x: 0.6018229
#     y: 0.68663454
#   }
#   relative_keypoints {
#     x: 0.52675897
#     y: 0.7997828
#   }
#   relative_keypoints {
#     x: 0.52100277
#     y: 0.8884832
#   }
#   relative_keypoints {
#     x: 0.37256604
#     y: 0.69735104
#   }
#   relative_keypoints {
#     x: 0.6751421
#     y: 0.7271886
#   }
# }
#
# label_id: 0
# score: 0.9500547
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34766045
#     ymin: 0.53673846
#     width: 0.3567563
#     height: 0.47564322
#   }
#   relative_keypoints {
#     x: 0.45478442
#     y: 0.66502815
#   }
#   relative_keypoints {
#     x: 0.6015081
#     y: 0.6742038
#   }
#   relative_keypoints {
#     x: 0.5257001
#     y: 0.7892758
#   }
#   relative_keypoints {
#     x: 0.52242947
#     y: 0.883815
#   }
#   relative_keypoints {
#     x: 0.37208864
#     y: 0.70049876
#   }
#   relative_keypoints {
#     x: 0.6789632
#     y: 0.7182662
#   }
# }
#
# label_id: 0
# score: 0.9635809
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3499241
#     ymin: 0.5339146
#     width: 0.35523558
#     height: 0.4736181
#   }
#   relative_keypoints {
#     x: 0.45116106
#     y: 0.6618507
#   }
#   relative_keypoints {
#     x: 0.59788746
#     y: 0.66995907
#   }
#   relative_keypoints {
#     x: 0.5191437
#     y: 0.7848799
#   }
#   relative_keypoints {
#     x: 0.5176676
#     y: 0.87902147
#   }
#   relative_keypoints {
#     x: 0.37437016
#     y: 0.6977179
#   }
#   relative_keypoints {
#     x: 0.6810762
#     y: 0.7139023
#   }
# }
# label_id: 0
# score: 0.95510525
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34910873
#     ymin: 0.5322092
#     width: 0.3516946
#     height: 0.468898
#   }
#   relative_keypoints {
#     x: 0.4503925
#     y: 0.65626174
#   }
#   relative_keypoints {
#     x: 0.596304
#     y: 0.6666232
#   }
#   relative_keypoints {
#     x: 0.5181509
#     y: 0.7780623
#   }
#   relative_keypoints {
#     x: 0.5153569
#     y: 0.8720898
#   }
#   relative_keypoints {
#     x: 0.37216333
#     y: 0.6917127
#   }
#   relative_keypoints {
#     x: 0.67733306
#     y: 0.7127481
#   }
# }
#
# label_id: 0
# score: 0.9499777
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34983784
#     ymin: 0.53121287
#     width: 0.34994626
#     height: 0.46656752
#   }
#   relative_keypoints {
#     x: 0.44959888
#     y: 0.65211433
#   }
#   relative_keypoints {
#     x: 0.5963228
#     y: 0.6642836
#   }
#   relative_keypoints {
#     x: 0.5163706
#     y: 0.7721693
#   }
#   relative_keypoints {
#     x: 0.512861
#     y: 0.86719257
#   }
#   relative_keypoints {
#     x: 0.3711824
#     y: 0.68854135
#   }
#   relative_keypoints {
#     x: 0.6775189
#     y: 0.7143085
#   }
# }
#
# label_id: 0
# score: 0.9472522
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34771842
#     ymin: 0.52562696
#     width: 0.34963948
#     height: 0.46615803
#   }
#   relative_keypoints {
#     x: 0.44823614
#     y: 0.6525567
#   }
#   relative_keypoints {
#     x: 0.5932489
#     y: 0.6624977
#   }
#   relative_keypoints {
#     x: 0.5157132
#     y: 0.7760888
#   }
#   relative_keypoints {
#     x: 0.51281893
#     y: 0.867096
#   }
#   relative_keypoints {
#     x: 0.3703662
#     y: 0.68250626
#   }
#   relative_keypoints {
#     x: 0.67310417
#     y: 0.70362943
#   }
# }
#
# label_id: 0
# score: 0.9307865
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35005212
#     ymin: 0.5289037
#     width: 0.34366977
#     height: 0.45819944
#   }
#   relative_keypoints {
#     x: 0.44765556
#     y: 0.6547687
#   }
#   relative_keypoints {
#     x: 0.5909228
#     y: 0.6643029
#   }
#   relative_keypoints {
#     x: 0.5142573
#     y: 0.7765873
#   }
#   relative_keypoints {
#     x: 0.5119745
#     y: 0.86502236
#   }
#   relative_keypoints {
#     x: 0.37175858
#     y: 0.6831446
#   }
#   relative_keypoints {
#     x: 0.67080253
#     y: 0.70288426
#   }
# }
#
# label_id: 0
# score: 0.931598
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34494275
#     ymin: 0.5202455
#     width: 0.3487394
#     height: 0.46495616
#   }
#   relative_keypoints {
#     x: 0.44561908
#     y: 0.64926237
#   }
#   relative_keypoints {
#     x: 0.58891493
#     y: 0.6602927
#   }
#   relative_keypoints {
#     x: 0.5112539
#     y: 0.7764217
#   }
#   relative_keypoints {
#     x: 0.5085834
#     y: 0.8644908
#   }
#   relative_keypoints {
#     x: 0.36971256
#     y: 0.6737461
#   }
#   relative_keypoints {
#     x: 0.6681775
#     y: 0.6965101
#   }
# }
#
# label_id: 0
# score: 0.9214759
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35085258
#     ymin: 0.5257788
#     width: 0.3388526
#     height: 0.45177633
#   }
#   relative_keypoints {
#     x: 0.44630063
#     y: 0.6442964
#   }
#   relative_keypoints {
#     x: 0.58729494
#     y: 0.6593609
#   }
#   relative_keypoints {
#     x: 0.5074577
#     y: 0.7652958
#   }
#   relative_keypoints {
#     x: 0.50421
#     y: 0.854009
#   }
#   relative_keypoints {
#     x: 0.3737309
#     y: 0.6731117
#   }
#   relative_keypoints {
#     x: 0.6677203
#     y: 0.7049046
#   }
# }
#
# label_id: 0
# score: 0.91429317
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35306457
#     ymin: 0.52839905
#     width: 0.33186796
#     height: 0.4424677
#   }
#   relative_keypoints {
#     x: 0.44464022
#     y: 0.6427297
#   }
#   relative_keypoints {
#     x: 0.58422405
#     y: 0.6580424
#   }
#   relative_keypoints {
#     x: 0.50428176
#     y: 0.76034063
#   }
#   relative_keypoints {
#     x: 0.5010971
#     y: 0.84870154
#   }
#   relative_keypoints {
#     x: 0.37384525
#     y: 0.67254204
#   }
#   relative_keypoints {
#     x: 0.6650497
#     y: 0.7056255
#   }
# }
#
# label_id: 0
# score: 0.91128516
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35104808
#     ymin: 0.53155607
#     width: 0.33029273
#     height: 0.44036686
#   }
#   relative_keypoints {
#     x: 0.44390792
#     y: 0.6446441
#   }
#   relative_keypoints {
#     x: 0.583282
#     y: 0.660249
#   }
#   relative_keypoints {
#     x: 0.504758
#     y: 0.76082873
#   }
#   relative_keypoints {
#     x: 0.5006388
#     y: 0.8492654
#   }
#   relative_keypoints {
#     x: 0.3703934
#     y: 0.6747648
#   }
#   relative_keypoints {
#     x: 0.66151357
#     y: 0.7088774
#   }
# }
#
# label_id: 0
# score: 0.9063294
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34573177
#     ymin: 0.5279632
#     width: 0.33204344
#     height: 0.4426993
#   }
#   relative_keypoints {
#     x: 0.44368795
#     y: 0.6417262
#   }
#   relative_keypoints {
#     x: 0.5825043
#     y: 0.6609538
#   }
#   relative_keypoints {
#     x: 0.5046284
#     y: 0.76143926
#   }
#   relative_keypoints {
#     x: 0.4979586
#     y: 0.84840626
#   }
#   relative_keypoints {
#     x: 0.36591032
#     y: 0.66758466
#   }
#   relative_keypoints {
#     x: 0.65636986
#     y: 0.7094025
#   }
# }
#
# label_id: 0
# score: 0.89966625
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34590057
#     ymin: 0.52861
#     width: 0.32986662
#     height: 0.43979686
#   }
#   relative_keypoints {
#     x: 0.44239417
#     y: 0.6449402
#   }
#   relative_keypoints {
#     x: 0.5793421
#     y: 0.66167647
#   }
#   relative_keypoints {
#     x: 0.50289917
#     y: 0.7643475
#   }
#   relative_keypoints {
#     x: 0.49743715
#     y: 0.8490625
#   }
#   relative_keypoints {
#     x: 0.36714685
#     y: 0.66931564
#   }
#   relative_keypoints {
#     x: 0.653778
#     y: 0.70576566
#   }
# }
#
# label_id: 0
# score: 0.9136663
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34575847
#     ymin: 0.52887946
#     width: 0.32836726
#     height: 0.43779826
#   }
#   relative_keypoints {
#     x: 0.44283113
#     y: 0.6464773
#   }
#   relative_keypoints {
#     x: 0.57803047
#     y: 0.6633826
#   }
#   relative_keypoints {
#     x: 0.5027169
#     y: 0.76764566
#   }
#   relative_keypoints {
#     x: 0.4971167
#     y: 0.84987277
#   }
#   relative_keypoints {
#     x: 0.3677319
#     y: 0.6678162
#   }
#   relative_keypoints {
#     x: 0.65104437
#     y: 0.7044068
#   }
# }
#
# label_id: 0
# score: 0.92421764
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35439885
#     ymin: 0.52732515
#     width: 0.32343042
#     height: 0.43121797
#   }
#   relative_keypoints {
#     x: 0.44640785
#     y: 0.6415437
#   }
#   relative_keypoints {
#     x: 0.57930577
#     y: 0.6582609
#   }
#   relative_keypoints {
#     x: 0.5028051
#     y: 0.75959724
#   }
#   relative_keypoints {
#     x: 0.49840686
#     y: 0.8423355
#   }
#   relative_keypoints {
#     x: 0.3769388
#     y: 0.66515964
#   }
#   relative_keypoints {
#     x: 0.65550256
#     y: 0.70139176
#   }
# }
#
# label_id: 0
# score: 0.92296374
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36201057
#     ymin: 0.5186271
#     width: 0.3136795
#     height: 0.41821742
#   }
#   relative_keypoints {
#     x: 0.45444998
#     y: 0.62707347
#   }
#   relative_keypoints {
#     x: 0.58437157
#     y: 0.6415153
#   }
#   relative_keypoints {
#     x: 0.51428235
#     y: 0.73799807
#   }
#   relative_keypoints {
#     x: 0.50988847
#     y: 0.8218784
#   }
#   relative_keypoints {
#     x: 0.38156268
#     y: 0.6571961
#   }
#   relative_keypoints {
#     x: 0.654494
#     y: 0.68564624
#   }
# }
#
# label_id: 0
# score: 0.9298196
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36881617
#     ymin: 0.48193115
#     width: 0.3087261
#     height: 0.41161084
#   }
#   relative_keypoints {
#     x: 0.4659759
#     y: 0.5906245
#   }
#   relative_keypoints {
#     x: 0.59474397
#     y: 0.6081469
#   }
#   relative_keypoints {
#     x: 0.5285217
#     y: 0.703034
#   }
#   relative_keypoints {
#     x: 0.5208938
#     y: 0.7834167
#   }
#   relative_keypoints {
#     x: 0.3860067
#     y: 0.61366826
#   }
#   relative_keypoints {
#     x: 0.65643084
#     y: 0.6480102
#   }
# }
#
# label_id: 0
# score: 0.9181164
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3735213
#     ymin: 0.44702697
#     width: 0.31446698
#     height: 0.41926724
#   }
#   relative_keypoints {
#     x: 0.45836875
#     y: 0.55503017
#   }
#   relative_keypoints {
#     x: 0.5930912
#     y: 0.5635081
#   }
#   relative_keypoints {
#     x: 0.51865745
#     y: 0.6587956
#   }
#   relative_keypoints {
#     x: 0.5173676
#     y: 0.7462185
#   }
#   relative_keypoints {
#     x: 0.38994324
#     y: 0.59229475
#   }
#   relative_keypoints {
#     x: 0.6712912
#     y: 0.6119372
#   }
# }
#
# label_id: 0
# score: 0.96199524
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37522036
#     ymin: 0.40852767
#     width: 0.32324952
#     height: 0.43098366
#   }
#   relative_keypoints {
#     x: 0.47314876
#     y: 0.523587
#   }
#   relative_keypoints {
#     x: 0.6064917
#     y: 0.53223413
#   }
#   relative_keypoints {
#     x: 0.5384486
#     y: 0.63422966
#   }
#   relative_keypoints {
#     x: 0.53467315
#     y: 0.71887106
#   }
#   relative_keypoints {
#     x: 0.39705452
#     y: 0.55707043
#   }
#   relative_keypoints {
#     x: 0.6763191
#     y: 0.5754554
#   }
# }
#
# label_id: 0
# score: 0.92907035
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38959172
#     ymin: 0.3912394
#     width: 0.30269387
#     height: 0.4035774
#   }
#   relative_keypoints {
#     x: 0.47534823
#     y: 0.4914158
#   }
#   relative_keypoints {
#     x: 0.6079642
#     y: 0.5088992
#   }
#   relative_keypoints {
#     x: 0.53557694
#     y: 0.5942061
#   }
#   relative_keypoints {
#     x: 0.5296116
#     y: 0.6789978
#   }
#   relative_keypoints {
#     x: 0.40014237
#     y: 0.5246694
#   }
#   relative_keypoints {
#     x: 0.67784715
#     y: 0.56052035
#   }
# }
#
# label_id: 0
# score: 0.909382
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38462406
#     ymin: 0.34508568
#     width: 0.3159796
#     height: 0.421292
#   }
#   relative_keypoints {
#     x: 0.47608918
#     y: 0.45204246
#   }
#   relative_keypoints {
#     x: 0.60816354
#     y: 0.46976084
#   }
#   relative_keypoints {
#     x: 0.5335859
#     y: 0.5644968
#   }
#   relative_keypoints {
#     x: 0.52873456
#     y: 0.6505899
#   }
#   relative_keypoints {
#     x: 0.40468353
#     y: 0.4809515
#   }
#   relative_keypoints {
#     x: 0.6807085
#     y: 0.51726097
#   }
# }
#
# label_id: 0
# score: 0.90373826
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38916528
#     ymin: 0.30814284
#     width: 0.31097418
#     height: 0.41460335
#   }
#   relative_keypoints {
#     x: 0.48128524
#     y: 0.4163378
#   }
#   relative_keypoints {
#     x: 0.60961616
#     y: 0.43504673
#   }
#   relative_keypoints {
#     x: 0.53845906
#     y: 0.5301272
#   }
#   relative_keypoints {
#     x: 0.5324989
#     y: 0.611839
#   }
#   relative_keypoints {
#     x: 0.40883744
#     y: 0.44029415
#   }
#   relative_keypoints {
#     x: 0.6772719
#     y: 0.4771663
#   }
# }
#
# label_id: 0
# score: 0.89770406
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38716757
#     ymin: 0.2577759
#     width: 0.31384254
#     height: 0.41843426
#   }
#   relative_keypoints {
#     x: 0.4773531
#     y: 0.36540157
#   }
#   relative_keypoints {
#     x: 0.61027986
#     y: 0.38296777
#   }
#   relative_keypoints {
#     x: 0.53645736
#     y: 0.47767276
#   }
#   relative_keypoints {
#     x: 0.5316053
#     y: 0.56270844
#   }
#   relative_keypoints {
#     x: 0.40458733
#     y: 0.39126486
#   }
#   relative_keypoints {
#     x: 0.682426
#     y: 0.42646688
#   }
# }
# label_id: 0
# score: 0.89871126
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38473365
#     ymin: 0.20056291
#     width: 0.3246483
#     height: 0.4328397
#   }
#   relative_keypoints {
#     x: 0.47873282
#     y: 0.31370598
#   }
#   relative_keypoints {
#     x: 0.61767966
#     y: 0.3367983
#   }
#   relative_keypoints {
#     x: 0.54055476
#     y: 0.43603367
#   }
#   relative_keypoints {
#     x: 0.5339552
#     y: 0.52096933
#   }
#   relative_keypoints {
#     x: 0.399197
#     y: 0.33400232
#   }
#   relative_keypoints {
#     x: 0.69006914
#     y: 0.3771755
#   }
# }
#
# label_id: 0
# score: 0.9360753
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37437043
#     ymin: 0.15663843
#     width: 0.3326815
#     height: 0.44355357
#   }
#   relative_keypoints {
#     x: 0.47052458
#     y: 0.272721
#   }
#   relative_keypoints {
#     x: 0.60987943
#     y: 0.28771335
#   }
#   relative_keypoints {
#     x: 0.5340456
#     y: 0.39116353
#   }
#   relative_keypoints {
#     x: 0.5300929
#     y: 0.47918385
#   }
#   relative_keypoints {
#     x: 0.3943714
#     y: 0.3020025
#   }
#   relative_keypoints {
#     x: 0.68613523
#     y: 0.33142042
#   }
# }
#
# label_id: 0
# score: 0.94890225
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37314838
#     ymin: 0.11793716
#     width: 0.34459484
#     height: 0.45942748
#   }
#   relative_keypoints {
#     x: 0.47062224
#     y: 0.24575879
#   }
#   relative_keypoints {
#     x: 0.612053
#     y: 0.26297367
#   }
#   relative_keypoints {
#     x: 0.5308066
#     y: 0.37608135
#   }
#   relative_keypoints {
#     x: 0.52615875
#     y: 0.4589569
#   }
#   relative_keypoints {
#     x: 0.39732572
#     y: 0.26251704
#   }
#   relative_keypoints {
#     x: 0.6916627
#     y: 0.29953712
#   }
# }
#
# label_id: 0
# score: 0.94545275
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36716923
#     ymin: 0.10786827
#     width: 0.3514574
#     height: 0.46857274
#   }
#   relative_keypoints {
#     x: 0.46773618
#     y: 0.24015512
#   }
#   relative_keypoints {
#     x: 0.6103301
#     y: 0.255718
#   }
#   relative_keypoints {
#     x: 0.52927125
#     y: 0.3730991
#   }
#   relative_keypoints {
#     x: 0.52499056
#     y: 0.4572755
#   }
#   relative_keypoints {
#     x: 0.39385822
#     y: 0.25838554
#   }
#   relative_keypoints {
#     x: 0.6895776
#     y: 0.29152852
#   }
# }
#
# label_id: 0
# score: 0.9572353
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36802986
#     ymin: 0.14102243
#     width: 0.34833142
#     height: 0.46441203
#   }
#   relative_keypoints {
#     x: 0.4697271
#     y: 0.2689758
#   }
#   relative_keypoints {
#     x: 0.6096002
#     y: 0.28083968
#   }
#   relative_keypoints {
#     x: 0.53373486
#     y: 0.39627814
#   }
#   relative_keypoints {
#     x: 0.5307775
#     y: 0.48416513
#   }
#   relative_keypoints {
#     x: 0.39538872
#     y: 0.29416418
#   }
#   relative_keypoints {
#     x: 0.6885876
#     y: 0.31745952
#   }
# }
#
# label_id: 0
# score: 0.92707944
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37482548
#     ymin: 0.17595889
#     width: 0.33265972
#     height: 0.4435293
#   }
#   relative_keypoints {
#     x: 0.46667767
#     y: 0.2986104
#   }
#   relative_keypoints {
#     x: 0.6054493
#     y: 0.31097293
#   }
#   relative_keypoints {
#     x: 0.52781945
#     y: 0.4214337
#   }
#   relative_keypoints {
#     x: 0.5259204
#     y: 0.50479907
#   }
#   relative_keypoints {
#     x: 0.3962262
#     y: 0.32113826
#   }
#   relative_keypoints {
#     x: 0.68579197
#     y: 0.34648198
#   }
# }
#
# label_id: 0
# score: 0.94014287
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.372186
#     ymin: 0.19225125
#     width: 0.33006924
#     height: 0.4400758
#   }
#   relative_keypoints {
#     x: 0.4669822
#     y: 0.30855417
#   }
#   relative_keypoints {
#     x: 0.6055334
#     y: 0.32419074
#   }
#   relative_keypoints {
#     x: 0.5294062
#     y: 0.4285112
#   }
#   relative_keypoints {
#     x: 0.52510875
#     y: 0.5132666
#   }
#   relative_keypoints {
#     x: 0.39124095
#     y: 0.33355588
#   }
#   relative_keypoints {
#     x: 0.68135595
#     y: 0.36565095
#   }
# }
#
# label_id: 0
# score: 0.9638161
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3715366
#     ymin: 0.22641845
#     width: 0.31693494
#     height: 0.42256117
#   }
#   relative_keypoints {
#     x: 0.4719896
#     y: 0.34589016
#   }
#   relative_keypoints {
#     x: 0.60183024
#     y: 0.3574373
#   }
#   relative_keypoints {
#     x: 0.53849906
#     y: 0.46383554
#   }
#   relative_keypoints {
#     x: 0.53251845
#     y: 0.5406191
#   }
#   relative_keypoints {
#     x: 0.39127082
#     y: 0.36402237
#   }
#   relative_keypoints {
#     x: 0.6638878
#     y: 0.38676757
#   }
# }
#
# label_id: 0
# score: 0.9285249
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37327668
#     ymin: 0.26144463
#     width: 0.31259105
#     height: 0.41676253
#   }
#   relative_keypoints {
#     x: 0.46437487
#     y: 0.37748986
#   }
#   relative_keypoints {
#     x: 0.5924883
#     y: 0.3899874
#   }
#   relative_keypoints {
#     x: 0.52287024
#     y: 0.49323696
#   }
#   relative_keypoints {
#     x: 0.51959294
#     y: 0.5710192
#   }
#   relative_keypoints {
#     x: 0.39514798
#     y: 0.39712173
#   }
#   relative_keypoints {
#     x: 0.6634333
#     y: 0.42266303
#   }
# }
#
# label_id: 0
# score: 0.93382865
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38092583
#     ymin: 0.28719598
#     width: 0.30317432
#     height: 0.40421218
#   }
#   relative_keypoints {
#     x: 0.4620609
#     y: 0.394458
#   }
#   relative_keypoints {
#     x: 0.5909378
#     y: 0.4031968
#   }
#   relative_keypoints {
#     x: 0.51786554
#     y: 0.49883968
#   }
#   relative_keypoints {
#     x: 0.51640016
#     y: 0.5796264
#   }
#   relative_keypoints {
#     x: 0.39812237
#     y: 0.4243117
#   }
#   relative_keypoints {
#     x: 0.66739345
#     y: 0.44560647
#   }
# }
#
# label_id: 0
# score: 0.9359718
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38220763
#     ymin: 0.28372198
#     width: 0.30289584
#     height: 0.40384167
#   }
#   relative_keypoints {
#     x: 0.46112978
#     y: 0.38863784
#   }
#   relative_keypoints {
#     x: 0.5914479
#     y: 0.39687043
#   }
#   relative_keypoints {
#     x: 0.51706785
#     y: 0.49034035
#   }
#   relative_keypoints {
#     x: 0.5160575
#     y: 0.57300043
#   }
#   relative_keypoints {
#     x: 0.3976867
#     y: 0.42251366
#   }
#   relative_keypoints {
#     x: 0.67019016
#     y: 0.44301337
#   }
# }
#
# label_id: 0
# score: 0.9391059
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3796621
#     ymin: 0.29153234
#     width: 0.29856676
#     height: 0.39806724
#   }
#   relative_keypoints {
#     x: 0.46075454
#     y: 0.39706928
#   }
#   relative_keypoints {
#     x: 0.5884953
#     y: 0.40878117
#   }
#   relative_keypoints {
#     x: 0.5163679
#     y: 0.5022953
#   }
#   relative_keypoints {
#     x: 0.51391923
#     y: 0.5805468
#   }
#   relative_keypoints {
#     x: 0.39554054
#     y: 0.42356795
#   }
#   relative_keypoints {
#     x: 0.66203904
#     y: 0.44972944
#   }
# }
#
# label_id: 0
# score: 0.9674009
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38823807
#     ymin: 0.33064437
#     width: 0.28391904
#     height: 0.37854844
#   }
#   relative_keypoints {
#     x: 0.47003847
#     y: 0.43060666
#   }
#   relative_keypoints {
#     x: 0.5894919
#     y: 0.44391805
#   }
#   relative_keypoints {
#     x: 0.5241673
#     y: 0.5311851
#   }
#   relative_keypoints {
#     x: 0.5198792
#     y: 0.6047922
#   }
#   relative_keypoints {
#     x: 0.404087
#     y: 0.45374864
#   }
#   relative_keypoints {
#     x: 0.6547402
#     y: 0.4818535
#   }
# }
#
# label_id: 0
# score: 0.9668724
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3833654
#     ymin: 0.3433078
#     width: 0.28764123
#     height: 0.38351148
#   }
#   relative_keypoints {
#     x: 0.47287786
#     y: 0.44289714
#   }
#   relative_keypoints {
#     x: 0.59151274
#     y: 0.4594717
#   }
#   relative_keypoints {
#     x: 0.5282338
#     y: 0.54697675
#   }
#   relative_keypoints {
#     x: 0.52142227
#     y: 0.62090737
#   }
#   relative_keypoints {
#     x: 0.40158927
#     y: 0.46437067
#   }
#   relative_keypoints {
#     x: 0.65130013
#     y: 0.4991055
#   }
# }
#
# label_id: 0
# score: 0.9692918
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38371038
#     ymin: 0.33527654
#     width: 0.290725
#     height: 0.3876227
#   }
#   relative_keypoints {
#     x: 0.47298786
#     y: 0.43850255
#   }
#   relative_keypoints {
#     x: 0.5923785
#     y: 0.4493677
#   }
#   relative_keypoints {
#     x: 0.53048044
#     y: 0.5405984
#   }
#   relative_keypoints {
#     x: 0.52566713
#     y: 0.61539334
#   }
#   relative_keypoints {
#     x: 0.40309685
#     y: 0.46372527
#   }
#   relative_keypoints {
#     x: 0.65385973
#     y: 0.4872417
#   }
# }
#
# label_id: 0
# score: 0.97577816
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38510597
#     ymin: 0.32823282
#     width: 0.29019904
#     height: 0.38692188
#   }
#   relative_keypoints {
#     x: 0.47524795
#     y: 0.43018442
#   }
#   relative_keypoints {
#     x: 0.59323096
#     y: 0.44233972
#   }
#   relative_keypoints {
#     x: 0.5318671
#     y: 0.5321245
#   }
#   relative_keypoints {
#     x: 0.5262196
#     y: 0.60680515
#   }
#   relative_keypoints {
#     x: 0.40474197
#     y: 0.45439053
#   }
#   relative_keypoints {
#     x: 0.6535153
#     y: 0.48100692
#   }
# }
#
# label_id: 0
# score: 0.96256834
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3853296
#     ymin: 0.34002274
#     width: 0.2922442
#     height: 0.38964897
#   }
#   relative_keypoints {
#     x: 0.4777642
#     y: 0.44529563
#   }
#   relative_keypoints {
#     x: 0.59564453
#     y: 0.4605741
#   }
#   relative_keypoints {
#     x: 0.53322256
#     y: 0.55365914
#   }
#   relative_keypoints {
#     x: 0.5271929
#     y: 0.6259043
#   }
#   relative_keypoints {
#     x: 0.40725848
#     y: 0.4640848
#   }
#   relative_keypoints {
#     x: 0.6549753
#     y: 0.49567598
#   }
# }
#
# label_id: 0
# score: 0.96582174
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38360628
#     ymin: 0.3554796
#     width: 0.29345736
#     height: 0.3912655
#   }
#   relative_keypoints {
#     x: 0.47384575
#     y: 0.46500826
#   }
#   relative_keypoints {
#     x: 0.5898141
#     y: 0.474752
#   }
#   relative_keypoints {
#     x: 0.52765226
#     y: 0.5729497
#   }
#   relative_keypoints {
#     x: 0.52453226
#     y: 0.6434767
#   }
#   relative_keypoints {
#     x: 0.40940756
#     y: 0.48519087
#   }
#   relative_keypoints {
#     x: 0.65369064
#     y: 0.50600195
#   }
# }
#
# label_id: 0
# score: 0.94907737
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3859467
#     ymin: 0.35850626
#     width: 0.29314536
#     height: 0.39084792
#   }
#   relative_keypoints {
#     x: 0.47125718
#     y: 0.469306
#   }
#   relative_keypoints {
#     x: 0.58746696
#     y: 0.47164434
#   }
#   relative_keypoints {
#     x: 0.5248958
#     y: 0.57102257
#   }
#   relative_keypoints {
#     x: 0.52512485
#     y: 0.64436316
#   }
#   relative_keypoints {
#     x: 0.41235915
#     y: 0.49746603
#   }
#   relative_keypoints {
#     x: 0.65700984
#     y: 0.5040998
#   }
# }
#
# label_id: 0
# score: 0.9601443
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38820118
#     ymin: 0.35153073
#     width: 0.29498327
#     height: 0.39329934
#   }
#   relative_keypoints {
#     x: 0.477539
#     y: 0.46187085
#   }
#   relative_keypoints {
#     x: 0.59412444
#     y: 0.46910393
#   }
#   relative_keypoints {
#     x: 0.53174114
#     y: 0.5681258
#   }
#   relative_keypoints {
#     x: 0.5296646
#     y: 0.64018315
#   }
#   relative_keypoints {
#     x: 0.41453102
#     y: 0.4854405
#   }
#   relative_keypoints {
#     x: 0.6598356
#     y: 0.5015085
#   }
# }
# label_id: 0
# score: 0.95069927
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3895925
#     ymin: 0.3566659
#     width: 0.2964231
#     height: 0.3952192
#   }
#   relative_keypoints {
#     x: 0.47332796
#     y: 0.4732837
#   }
#   relative_keypoints {
#     x: 0.59105444
#     y: 0.4806692
#   }
#   relative_keypoints {
#     x: 0.52458894
#     y: 0.5849621
#   }
#   relative_keypoints {
#     x: 0.52470964
#     y: 0.6536768
#   }
#   relative_keypoints {
#     x: 0.41679332
#     y: 0.48850238
#   }
#   relative_keypoints {
#     x: 0.66352004
#     y: 0.5042072
#   }
# }
#
# label_id: 0
# score: 0.9359211
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39218608
#     ymin: 0.37166095
#     width: 0.29279736
#     height: 0.3903842
#   }
#   relative_keypoints {
#     x: 0.47771108
#     y: 0.48051476
#   }
#   relative_keypoints {
#     x: 0.59581125
#     y: 0.4949894
#   }
#   relative_keypoints {
#     x: 0.5285369
#     y: 0.5913078
#   }
#   relative_keypoints {
#     x: 0.52517503
#     y: 0.662656
#   }
#   relative_keypoints {
#     x: 0.41547596
#     y: 0.49662304
#   }
#   relative_keypoints {
#     x: 0.66363764
#     y: 0.52641135
#   }
# }
#
# label_id: 0
# score: 0.9254153
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3944575
#     ymin: 0.37600148
#     width: 0.29233065
#     height: 0.3897618
#   }
#   relative_keypoints {
#     x: 0.48060778
#     y: 0.48743302
#   }
#   relative_keypoints {
#     x: 0.5969642
#     y: 0.502569
#   }
#   relative_keypoints {
#     x: 0.5307351
#     y: 0.60115093
#   }
#   relative_keypoints {
#     x: 0.5271504
#     y: 0.66996783
#   }
#   relative_keypoints {
#     x: 0.41892478
#     y: 0.4984221
#   }
#   relative_keypoints {
#     x: 0.6634853
#     y: 0.529514
#   }
# }
#
# label_id: 0
# score: 0.928435
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39480838
#     ymin: 0.36943007
#     width: 0.2976888
#     height: 0.39690572
#   }
#   relative_keypoints {
#     x: 0.4799415
#     y: 0.48443627
#   }
#   relative_keypoints {
#     x: 0.59804636
#     y: 0.4952888
#   }
#   relative_keypoints {
#     x: 0.53048015
# ...
#   relative_keypoints {
#     x: 0.41105813
#     y: 0.5488801
#   }
#   relative_keypoints {
#     x: 0.65972483
#     y: 0.5780038
#   }
# }
#
# label_id: 0
# score: 0.96221215
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38127637
#     ymin: 0.41741127
#     width: 0.303846
#     height: 0.40511096
#   }
#   relative_keypoints {
#     x: 0.48049474
#     y: 0.534177
#   }
#   relative_keypoints {
#     x: 0.6008551
#     y: 0.54597515
#   }
#   relative_keypoints {
#     x: 0.53997445
#     y: 0.65031916
#   }
#   relative_keypoints {
#     x: 0.53453463
#     y: 0.7208788
#   }
#   relative_keypoints {
#     x: 0.4077094
#     y: 0.54947835
#   }
#   relative_keypoints {
#     x: 0.6594765
#     y: 0.5736058
#   }
# }
#
# label_id: 0
# score: 0.95978796
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38415748
#     ymin: 0.41609806
#     width: 0.30461836
#     height: 0.40614104
#   }
#   relative_keypoints {
#     x: 0.48082337
#     y: 0.5338359
#   }
#   relative_keypoints {
#     x: 0.60108536
#     y: 0.54801756
#   }
#   relative_keypoints {
#     x: 0.53691876
#     y: 0.6531603
#   }
#   relative_keypoints {
#     x: 0.5320108
#     y: 0.72254133
#   }
#   relative_keypoints {
#     x: 0.41204122
#     y: 0.5458587
#   }
#   relative_keypoints {
#     x: 0.66304976
#     y: 0.57426924
#   }
# }
#
# label_id: 0
# score: 0.9668814
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38254353
#     ymin: 0.41661835
#     width: 0.302955
#     height: 0.40392345
#   }
#   relative_keypoints {
#     x: 0.48236105
#     y: 0.533125
#   }
#   relative_keypoints {
#     x: 0.60086423
#     y: 0.5472879
#   }
#   relative_keypoints {
#     x: 0.53954357
#     y: 0.65137035
#   }
#   relative_keypoints {
#     x: 0.53342825
#     y: 0.720244
#   }
#   relative_keypoints {
#     x: 0.41073126
#     y: 0.544838
#   }
#   relative_keypoints {
#     x: 0.6587071
#     y: 0.57393783
#   }
# }
#
# label_id: 0
# score: 0.9628026
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3801542
#     ymin: 0.41419935
#     width: 0.30658346
#     height: 0.40876108
#   }
#   relative_keypoints {
#     x: 0.48035544
#     y: 0.5340144
#   }
#   relative_keypoints {
#     x: 0.6014784
#     y: 0.54630893
#   }
#   relative_keypoints {
#     x: 0.53996414
#     y: 0.65339875
#   }
#   relative_keypoints {
#     x: 0.5346018
#     y: 0.72270054
#   }
#   relative_keypoints {
#     x: 0.40748468
#     y: 0.5467344
#   }
#   relative_keypoints {
#     x: 0.66016316
#     y: 0.57125235
#   }
# }
#
# label_id: 0
# score: 0.9651343
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38113657
#     ymin: 0.41511458
#     width: 0.30331096
#     height: 0.40439808
#   }
#   relative_keypoints {
#     x: 0.4809267
#     y: 0.53261477
#   }
#   relative_keypoints {
#     x: 0.6009232
#     y: 0.54407793
#   }
#   relative_keypoints {
#     x: 0.5408754
#     y: 0.64902955
#   }
#   relative_keypoints {
#     x: 0.5353052
#     y: 0.71866816
#   }
#   relative_keypoints {
#     x: 0.40755156
#     y: 0.5468374
#   }
#   relative_keypoints {
#     x: 0.6583595
#     y: 0.57026106
#   }
# }
# label_id: 0
# score: 0.9621603
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38100502
#     ymin: 0.4147886
#     width: 0.30510518
#     height: 0.4067908
#   }
#   relative_keypoints {
#     x: 0.48229507
#     y: 0.5324481
#   }
#   relative_keypoints {
#     x: 0.60187036
#     y: 0.5467468
#   }
#   relative_keypoints {
#     x: 0.5404979
#     y: 0.6518478
#   }
#   relative_keypoints {
#     x: 0.53396064
#     y: 0.72132784
#   }
#   relative_keypoints {
#     x: 0.4088657
#     y: 0.54413295
#   }
#   relative_keypoints {
#     x: 0.65868723
#     y: 0.57330936
#   }
# }
#
# label_id: 0
# score: 0.96713823
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38251835
#     ymin: 0.41495925
#     width: 0.30487
#     height: 0.40647674
#   }
#   relative_keypoints {
#     x: 0.4822471
#     y: 0.53148055
#   }
#   relative_keypoints {
#     x: 0.6016139
#     y: 0.5430527
#   }
#   relative_keypoints {
#     x: 0.5403271
#     y: 0.64748996
#   }
#   relative_keypoints {
#     x: 0.534811
#     y: 0.7182241
#   }
#   relative_keypoints {
#     x: 0.41060624
#     y: 0.54733497
#   }
#   relative_keypoints {
#     x: 0.6604618
#     y: 0.57212275
#   }
# }
#
# label_id: 0
# score: 0.96336704
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37972453
#     ymin: 0.41552627
#     width: 0.30546144
#     height: 0.4072656
#   }
#   relative_keypoints {
#     x: 0.48303097
#     y: 0.5322426
#   }
#   relative_keypoints {
#     x: 0.6014216
#     y: 0.54544073
#   }
#   relative_keypoints {
#     x: 0.54193103
#     y: 0.64996177
#   }
#   relative_keypoints {
#     x: 0.53490525
#     y: 0.72050285
#   }
#   relative_keypoints {
#     x: 0.40838227
#     y: 0.5459475
#   }
#   relative_keypoints {
#     x: 0.6565769
#     y: 0.573823
#   }
# }
#
# label_id: 0
# score: 0.9640682
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38090625
#     ymin: 0.4145856
#     width: 0.3067167
#     height: 0.4089396
#   }
#   relative_keypoints {
#     x: 0.4818035
#     y: 0.53162605
#   }
#   relative_keypoints {
#     x: 0.60145587
#     y: 0.5456202
#   }
#   relative_keypoints {
#     x: 0.539164
#     y: 0.65047735
#   }
#   relative_keypoints {
#     x: 0.5329118
#     y: 0.7211423
#   }
#   relative_keypoints {
#     x: 0.4097228
#     y: 0.5453563
#   }
#   relative_keypoints {
#     x: 0.65994775
#     y: 0.5746417
#   }
# }
#
# label_id: 0
# score: 0.96550435
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38243985
#     ymin: 0.41546792
#     width: 0.30520833
#     height: 0.4069277
#   }
#   relative_keypoints {
#     x: 0.4821342
#     y: 0.53117615
#   }
#   relative_keypoints {
#     x: 0.60183847
#     y: 0.54360247
#   }
#   relative_keypoints {
#     x: 0.53999436
#     y: 0.6472616
#   }
#   relative_keypoints {
#     x: 0.53436816
#     y: 0.71882653
#   }
#   relative_keypoints {
#     x: 0.4105349
#     y: 0.5480013
#   }
#   relative_keypoints {
#     x: 0.6608135
#     y: 0.5743053
#   }
# }
#
# label_id: 0
# score: 0.9613332
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38060847
#     ymin: 0.4134397
#     width: 0.30798027
#     height: 0.41062367
#   }
#   relative_keypoints {
#     x: 0.48126826
#     y: 0.5315368
#   }
#   relative_keypoints {
#     x: 0.6018169
#     y: 0.544502
#   }
#   relative_keypoints {
#     x: 0.5394769
#     y: 0.650662
#   }
#   relative_keypoints {
#     x: 0.533959
#     y: 0.7218544
#   }
#   relative_keypoints {
#     x: 0.40963334
#     y: 0.54615587
#   }
#   relative_keypoints {
#     x: 0.6609043
#     y: 0.57260776
#   }
# }
#
# label_id: 0
# score: 0.9614149
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38037622
#     ymin: 0.4107626
#     width: 0.31082314
#     height: 0.41441417
#   }
#   relative_keypoints {
#     x: 0.48126203
#     y: 0.5295586
#   }
#   relative_keypoints {
#     x: 0.6020861
#     y: 0.543622
#   }
#   relative_keypoints {
#     x: 0.53804326
#     y: 0.65049845
#   }
#   relative_keypoints {
#     x: 0.53237486
#     y: 0.7219963
#   }
#   relative_keypoints {
#     x: 0.41067168
#     y: 0.5431471
#   }
#   relative_keypoints {
#     x: 0.66279125
#     y: 0.57252413
#   }
# }
#
# label_id: 0
# score: 0.96736854
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38389733
#     ymin: 0.41429478
#     width: 0.3043039
#     height: 0.40572232
#   }
#   relative_keypoints {
#     x: 0.48183107
#     y: 0.53074473
#   }
#   relative_keypoints {
#     x: 0.6018895
#     y: 0.54463816
#   }
#   relative_keypoints {
#     x: 0.5385715
#     y: 0.64860034
#   }
#   relative_keypoints {
#     x: 0.5330652
#     y: 0.71858144
#   }
#   relative_keypoints {
#     x: 0.41140032
#     y: 0.54403394
#   }
#   relative_keypoints {
#     x: 0.6621972
#     y: 0.5728362
#   }
# }
#
# label_id: 0
# score: 0.965978
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3805829
#     ymin: 0.41275728
#     width: 0.30750558
#     height: 0.4099909
#   }
#   relative_keypoints {
#     x: 0.48279384
#     y: 0.5320882
#   }
#   relative_keypoints {
#     x: 0.60342395
#     y: 0.544761
#   }
#   relative_keypoints {
#     x: 0.54255164
#     y: 0.65152043
#   }
#   relative_keypoints {
#     x: 0.536505
#     y: 0.72158045
#   }
#   relative_keypoints {
#     x: 0.4085243
#     y: 0.545125
#   }
#   relative_keypoints {
#     x: 0.6604146
#     y: 0.57081336
#   }
# }
#
# label_id: 0
# score: 0.9704851
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3849519
#     ymin: 0.41762275
#     width: 0.3011884
#     height: 0.4015689
#   }
#   relative_keypoints {
#     x: 0.48452628
#     y: 0.5321801
#   }
#   relative_keypoints {
#     x: 0.60310954
#     y: 0.5465452
#   }
#   relative_keypoints {
#     x: 0.542407
#     y: 0.64864993
#   }
#   relative_keypoints {
#     x: 0.53596014
#     y: 0.7180188
#   }
#   relative_keypoints {
#     x: 0.41155118
#     y: 0.5453076
#   }
#   relative_keypoints {
#     x: 0.6600636
#     y: 0.57498366
#   }
# }
#
# label_id: 0
# score: 0.9675739
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.383919
#     ymin: 0.4146551
#     width: 0.305426
#     height: 0.40721858
#   }
#   relative_keypoints {
#     x: 0.48381057
#     y: 0.5335851
#   }
#   relative_keypoints {
#     x: 0.60416216
#     y: 0.5459785
#   }
#   relative_keypoints {
#     x: 0.5426292
#     y: 0.6524095
#   }
#   relative_keypoints {
#     x: 0.53738654
#     y: 0.7215688
#   }
#   relative_keypoints {
#     x: 0.41180846
#     y: 0.546156
#   }
#   relative_keypoints {
#     x: 0.66279167
#     y: 0.5711389
#   }
# }
#
# label_id: 0
# score: 0.9644261
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38144204
#     ymin: 0.41492492
#     width: 0.3070688
#     height: 0.4094088
#   }
#   relative_keypoints {
#     x: 0.48249128
#     y: 0.5338655
#   }
#   relative_keypoints {
#     x: 0.60309374
#     y: 0.54495746
#   }
#   relative_keypoints {
#     x: 0.54234684
#     y: 0.6513223
#   }
#   relative_keypoints {
#     x: 0.5370938
#     y: 0.72202784
#   }
#   relative_keypoints {
#     x: 0.4093861
#     y: 0.5492067
#   }
#   relative_keypoints {
#     x: 0.66124904
#     y: 0.5717936
#   }
# }
#
# label_id: 0
# score: 0.9601276
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3807957
#     ymin: 0.41425598
#     width: 0.30588564
#     height: 0.40783083
#   }
#   relative_keypoints {
#     x: 0.48163855
#     y: 0.5327808
#   }
#   relative_keypoints {
#     x: 0.6018069
#     y: 0.54555315
#   }
#   relative_keypoints {
#     x: 0.54071385
#     y: 0.6515084
#   }
#   relative_keypoints {
#     x: 0.5348126
#     y: 0.721494
#   }
#   relative_keypoints {
#     x: 0.40834865
#     y: 0.54575366
#   }
#   relative_keypoints {
#     x: 0.65939194
#     y: 0.57149905
#   }
# }
#
# label_id: 0
# score: 0.9650271
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38090292
#     ymin: 0.41378653
#     width: 0.30753413
#     height: 0.41002935
#   }
#   relative_keypoints {
#     x: 0.48416743
#     y: 0.53395706
#   }
#   relative_keypoints {
#     x: 0.603684
#     y: 0.5460052
#   }
#   relative_keypoints {
#     x: 0.54387724
#     y: 0.65358776
#   }
#   relative_keypoints {
#     x: 0.5377406
#     y: 0.7227683
#   }
#   relative_keypoints {
#     x: 0.40997714
#     y: 0.54590416
#   }
#   relative_keypoints {
#     x: 0.6597182
#     y: 0.5707889
#   }
# }
#
# label_id: 0
# score: 0.9654609
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38233495
#     ymin: 0.41367394
#     width: 0.30624342
#     height: 0.40830845
#   }
#   relative_keypoints {
#     x: 0.4838434
#     y: 0.53211397
#   }
#   relative_keypoints {
#     x: 0.6034339
#     y: 0.544156
#   }
#   relative_keypoints {
#     x: 0.54279315
#     y: 0.65024537
#   }
#   relative_keypoints {
#     x: 0.5370082
#     y: 0.7204003
#   }
#   relative_keypoints {
#     x: 0.41086864
#     y: 0.5456443
#   }
#   relative_keypoints {
#     x: 0.6607742
#     y: 0.5705617
#   }
# }
#
# label_id: 0
# score: 0.962682
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38130054
#     ymin: 0.41381246
#     width: 0.3079464
#     height: 0.41057914
#   }
#   relative_keypoints {
#     x: 0.48274976
#     y: 0.532754
#   }
#   relative_keypoints {
#     x: 0.6025492
#     y: 0.5441942
#   }
#   relative_keypoints {
#     x: 0.54151297
#     y: 0.65089315
#   }
#   relative_keypoints {
#     x: 0.5359827
#     y: 0.7217702
#   }
#   relative_keypoints {
#     x: 0.41066724
#     y: 0.5473716
#   }
#   relative_keypoints {
#     x: 0.66111875
#     y: 0.5714174
#   }
# }
#
# label_id: 0
# score: 0.9669384
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.37966737
#     ymin: 0.41063827
#     width: 0.31257322
#     height: 0.41674852
#   }
#   relative_keypoints {
#     x: 0.4848718
#     y: 0.5324454
#   }
#   relative_keypoints {
#     x: 0.6046982
#     y: 0.5437277
#   }
#   relative_keypoints {
#     x: 0.54408383
#     y: 0.6532102
#   }
#   relative_keypoints {
#     x: 0.53792816
#     y: 0.7236523
#   }
#   relative_keypoints {
#     x: 0.411021
#     y: 0.54516035
#   }
#   relative_keypoints {
#     x: 0.66183794
#     y: 0.5697568
#   }
# }
#
# label_id: 0
# score: 0.96295655
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38088906
#     ymin: 0.41372442
#     width: 0.30827802
#     height: 0.41102123
#   }
#   relative_keypoints {
#     x: 0.4828291
#     y: 0.5340554
#   }
#   relative_keypoints {
#     x: 0.60347337
#     y: 0.5441553
#   }
#   relative_keypoints {
#     x: 0.543393
#     y: 0.65210444
#   }
#   relative_keypoints {
#     x: 0.5382331
#     y: 0.7226717
#   }
#   relative_keypoints {
#     x: 0.40922648
#     y: 0.54877657
#   }
#   relative_keypoints {
#     x: 0.6614082
#     y: 0.56974834
#   }
# }
#
# label_id: 0
# score: 0.9673382
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3805417
#     ymin: 0.411547
#     width: 0.31158063
#     height: 0.41542482
#   }
#   relative_keypoints {
#     x: 0.48255464
#     y: 0.53299236
#   }
#   relative_keypoints {
#     x: 0.6031219
#     y: 0.5426819
#   }
#   relative_keypoints {
#     x: 0.54156053
#     y: 0.65198594
#   }
#   relative_keypoints {
#     x: 0.53668493
#     y: 0.7228503
#   }
#   relative_keypoints {
#     x: 0.41120952
#     y: 0.547898
#   }
#   relative_keypoints {
#     x: 0.6632401
#     y: 0.56924695
#   }
# }
#
# label_id: 0
# score: 0.96914285
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38449106
#     ymin: 0.41377074
#     width: 0.30436787
#     height: 0.40580887
#   }
#   relative_keypoints {
#     x: 0.48611492
#     y: 0.5319559
#   }
#   relative_keypoints {
#     x: 0.6044304
#     y: 0.5445201
#   }
#   relative_keypoints {
#     x: 0.54448074
#     y: 0.65010834
#   }
#   relative_keypoints {
#     x: 0.5383111
#     y: 0.7188528
#   }
#   relative_keypoints {
#     x: 0.41294628
#     y: 0.5434911
#   }
#   relative_keypoints {
#     x: 0.66082364
#     y: 0.56978387
#   }
# }
# label_id: 0
# score: 0.96503484
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3854588
#     ymin: 0.41716903
#     width: 0.30370858
#     height: 0.4049294
#   }
#   relative_keypoints {
#     x: 0.48536813
#     y: 0.5348687
#   }
#   relative_keypoints {
#     x: 0.60442024
#     y: 0.54662675
#   }
#   relative_keypoints {
#     x: 0.54408264
#     y: 0.65168446
#   }
#   relative_keypoints {
#     x: 0.5385827
#     y: 0.72115093
#   }
#   relative_keypoints {
#     x: 0.41307312
#     y: 0.5482373
#   }
#   relative_keypoints {
#     x: 0.66247344
#     y: 0.5726125
#   }
# }
#
# label_id: 0
# score: 0.96637124
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3826456
#     ymin: 0.41476512
#     width: 0.30801094
#     height: 0.4106657
#   }
#   relative_keypoints {
#     x: 0.48620325
#     y: 0.5342185
#   }
#   relative_keypoints {
#     x: 0.60567
#     y: 0.54736656
#   }
#   relative_keypoints {
#     x: 0.5453452
#     y: 0.65421337
#   }
#   relative_keypoints {
#     x: 0.53876597
#     y: 0.72370553
#   }
#   relative_keypoints {
#     x: 0.41173956
#     y: 0.5454778
#   }
#   relative_keypoints {
#     x: 0.662169
#     y: 0.57315785
#   }
# }
#
# label_id: 0
# score: 0.9674022
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38541996
#     ymin: 0.41487116
#     width: 0.30558354
#     height: 0.40742922
#   }
#   relative_keypoints {
#     x: 0.48502186
#     y: 0.53594846
#   }
#   relative_keypoints {
#     x: 0.604672
#     y: 0.545208
#   }
#   relative_keypoints {
#     x: 0.5445457
#     y: 0.6534395
#   }
#   relative_keypoints {
#     x: 0.5402429
#     y: 0.72190195
#   }
#   relative_keypoints {
#     x: 0.41382995
#     y: 0.5487732
#   }
#   relative_keypoints {
#     x: 0.6640044
#     y: 0.5678536
#   }
# }
